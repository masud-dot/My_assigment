# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <b>Masud Mondal</b><br>
# Data Scientist

# %% [markdown]
# I am interested in data science because I would love to contribute towards affordable and quality health care in the feature.

# %% [markdown]
# <h3>The below should print 'Hello World!'</h3>

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# 1. Numbered item(i)
# 2. Numbered irem(ii)<br>
#     1. Sub Text(1)
#     2. Sub Text(2)
# -  Apple
# -  Mango
# ***
#
# <table>
#     <tr>
#         <td>First</td>
#         <td>Second</td>
#         <td>Third</td>
#     </tr>
#     <tr>
#         <td>Mango</td>
#         <td>Apple</td>
#         <td>Banana</td>
#     </tr>
# </table>
